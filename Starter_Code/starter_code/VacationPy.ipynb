# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
from pathlib import Path

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
csv_file = Path("../output_data/cities.csv")
city_data_df = pd.read_csv(csv_file)

# Display sample data
city_data_df.head()
# Out:
#    City_ID      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0  waitangi -43.9535 -176.5597     13.79        89          88
# 1        1     lensk  60.7253  114.9278     -2.17        97         100
# 2        2  qaqortoq  60.7167  -46.0333      2.66        66          53
# 3        3    badger  64.8000 -147.5333    -12.49        60          40
# 4        4  hermanus -34.4187   19.2345     21.56        85          99
#
#    Wind Speed Country        Date
# 0        3.13      NZ  1682260633
# 1        3.08      RU  1682260633
# 2        2.06      GL  1682260633
# 3       10.29      US  1682260634
# 4        4.21      ZA  1682260634

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
#%%capture --no-display

# Configure the map plot
# YOUR CODE HERE
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    scale = 0.5,
    color = "City"
)

# Display the map plot
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# YOUR CODE HERE
ideal_weather1 = city_data_df.loc[city_data_df['Max Temp']<12]
ideal_weather2 = ideal_weather1.loc[city_data_df['Max Temp']>0]
ideal_weather3 = ideal_weather2.loc[city_data_df['Wind Speed'] < 2]
# Drop any rows with null values
# YOUR CODE HERE
ideal_weather = ideal_weather3.dropna()

# Display sample data
# YOUR CODE HERE
ideal_weather
# Out:
#      City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 28        28         tambo -14.8000  -73.9167      8.65        51          38
# 53        53   new norfolk -42.7826  147.0587      8.17        61          15
# 85        85   novyy urgal  51.0736  132.5642      0.45        85         100
# 108      108      taskopru  41.5098   34.2141     11.30        87         100
# 167      167      kangding  30.0513  101.9603      8.07        87          81
# 183      183   kongsvinger  60.1905   11.9977      5.03        77         100
# 251      251     tucumcari  35.1717 -103.7250      7.19        60           0
# 285      285     ilulissat  69.2167  -51.1000      2.01        93         100
# 306      306      jincheng  35.5022  112.8328      2.67        98         100
# 307      307         ancud -41.8697  -73.8203     11.44        70          71
# 341      341          hovd  48.0056   91.6419      3.34        39          27
# 351      351      smithers  54.7804 -127.1743      4.18        93         100
# 357      357  puerto aysen -45.4000  -72.7000     10.88        87         100
# 377      377      karliova  39.2983   41.0142      8.10        83         100
# 387      387    mishelevka  52.8575  103.1719      1.41        68          29
# 393      393       quellon -43.1167  -73.6167     10.14       100          20
# 401      401      bereznik  62.8551   42.7072      2.39        74         100
# 430      430       chonchi -42.6128  -73.8092     11.73        73          89
# 434      434        hinton  53.4001 -117.5857      3.91        83         100
# 451      451      akureyri  65.6835  -18.0878      3.96        35           0
# 462      462     rio bueno -40.3167  -72.9667      8.08        61           8
# 516      516   akdagmadeni  39.6603   35.8836      9.93        76         100
#
#      Wind Speed Country        Date
# 28         1.95      PE  1682260644
# 53         1.60      AU  1682260652
# 85         1.72      RU  1682260660
# 108        1.72      TR  1682260667
# 167        1.50      CN  1682260684
# 183        1.63      NO  1682260689
# 251        1.54      US  1682260708
# 285        0.00      GL  1682260717
# 306        1.55      CN  1682260725
# 307        1.34      CL  1682260725
# 341        1.59      MN  1682260735
# 351        1.54      CA  1682260737
# 357        1.13      CL  1682260739
# 377        1.18      TR  1682260744
# 387        0.83      RU  1682260746
# 393        0.00      CL  1682260748
# 401        1.30      RU  1682260750
# 430        0.82      CL  1682260758
# 434        0.89      CA  1682260759
# 451        1.54      IS  1682260764
# 462        1.17      CL  1682260769
# 516        1.47      TR  1682260787

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
# YOUR CODE HERE
hotel_df = ideal_weather.copy()
hotel_df = hotel_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']]
# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
# YOUR CODE HERE
hotel_df.insert(5,'Hotel Name',"")

# Display sample data
# YOUR CODE HERE
hotel_df
# Out:
#              City Country      Lat       Lng  Humidity Hotel Name
# 28          tambo      PE -14.8000  -73.9167        51
# 53    new norfolk      AU -42.7826  147.0587        61
# 85    novyy urgal      RU  51.0736  132.5642        85
# 108      taskopru      TR  41.5098   34.2141        87
# 167      kangding      CN  30.0513  101.9603        87
# 183   kongsvinger      NO  60.1905   11.9977        77
# 251     tucumcari      US  35.1717 -103.7250        60
# 285     ilulissat      GL  69.2167  -51.1000        93
# 306      jincheng      CN  35.5022  112.8328        98
# 307         ancud      CL -41.8697  -73.8203        70
# 341          hovd      MN  48.0056   91.6419        39
# 351      smithers      CA  54.7804 -127.1743        93
# 357  puerto aysen      CL -45.4000  -72.7000        87
# 377      karliova      TR  39.2983   41.0142        83
# 387    mishelevka      RU  52.8575  103.1719        68
# 393       quellon      CL -43.1167  -73.6167       100
# 401      bereznik      RU  62.8551   42.7072        74
# 430       chonchi      CL -42.6128  -73.8092        73
# 434        hinton      CA  53.4001 -117.5857        83
# 451      akureyri      IS  65.6835  -18.0878        35
# 462     rio bueno      CL -40.3167  -72.9667        61
# 516   akdagmadeni      TR  39.6603   35.8836        76

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
###TEST ONLY###
base_url = "https://api.geoapify.com/v2/places?" + "categories=accommodation.hotel&filter=rect:11.573106549898483,48.13898913611139,11.57704581350751,48.13666585409989&limit=20" + "&apiKey=" + geoapify_key 
'''radius = 10000
categories = 'accommodation.hotel'
limit = 250
latitude = hotel_df['Lat']
longitude = hotel_df['Lng']
filter = f"circle:{longitude},{latitude},{radius}"
bias = f"proximity:{longitude},{latitude}"
params = {
    "categories":categories,
    
    #"limit":limit,
    "filter":filter,
    "bias":bias,
    "apiKey":geoapify_key  
          }'''
name_address = requests.get(base_url)
name_address = name_address.json()
name_address
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'name': 'Beyond by Geisel',
#     'country': 'Germany',
#     'country_code': 'de',
#     'state': 'Bavaria',
#     'city': 'Munich',
#     'postcode': '80331',
#     'district': 'Angerviertel',
#     'suburb': 'Altstadt-Lehel',
#     'quarter': 'Angerviertel',
#     'street': 'Marienplatz',
#     'housenumber': '22',
#     'lon': 11.5753783,
#     'lat': 48.1368481,
#     'formatted': 'Beyond by Geisel, Marienplatz 22, 80331 Munich, Germany',
#     'address_line1': 'Beyond by Geisel',
#     'address_line2': 'Marienplatz 22, 80331 Munich, Germany',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'internet_access',
#      'wheelchair',
#      'wheelchair.yes'],
#     'details': ['details', 'details.contact', 'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Beyond by Geisel',
#       'osm_id': 6413897463,
#       'tourism': 'hotel',
#       'osm_type': 'n',
#       'addr:city': 'München',
#       'wheelchair': 'yes',
#       'addr:street': 'Marienplatz',
#       'contact:fax': '+49.89.700746722',
#       'addr:country': 'DE',
#       'addr:postcode': 80331,
#       'contact:email': 'contact@beyond-muc.de',
#       'contact:phone': '+49.89.700746700',
#       'contact:website': 'https://www.beyond-muc.de/',
#       'internet_access': 'wlan',
#       'addr:housenumber': 22}},
#     'place_id': '51f9a70afc972627405938ce103d84114840f00103f901f74e4c7e010000009203104265796f6e642062792047656973656c'},
#    'geometry': {'type': 'Point',
#     'coordinates': [11.575378299999999, 48.13684809990485]}}]}

# %%
# Set parameters to search for a hotel
radius = 10000

params = {
    "categories":'accommodation.hotel',
    "limit": 20,
    "apiKey":geoapify_key  
          }

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    # YOUR CODE HERE
    latitude = row['Lat']
    longitude = row['Lng']
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# tambo - nearest hotel: No hotel found
# new norfolk - nearest hotel: Woodbridge on the Derwent
# novyy urgal - nearest hotel: No hotel found
# taskopru - nearest hotel: Poyraz Otel
# kangding - nearest hotel: Kalakaer hotel
# kongsvinger - nearest hotel: Vinger hotell
# tucumcari - nearest hotel: Pow Wow Inn
# ilulissat - nearest hotel: Best Western Plus Hotel Ilulissat
# jincheng - nearest hotel: 德豪宾馆
# ancud - nearest hotel: Cabañas
# hovd - nearest hotel: Khovd hotel
# smithers - nearest hotel: Sunshine Inn Hotel
# puerto aysen - nearest hotel: Hostal Dendal
# karliova - nearest hotel: No hotel found
# mishelevka - nearest hotel: No hotel found
# quellon - nearest hotel: Aliwen
# bereznik - nearest hotel: Отель Прибрежный
# chonchi - nearest hotel: Hotel Huildín
# hinton - nearest hotel: Timberland Hotel
# akureyri - nearest hotel: Hótel Norðurland
# rio bueno - nearest hotel: No hotel found
# akdagmadeni - nearest hotel: No hotel found
#              City Country      Lat       Lng  Humidity  \
# 28          tambo      PE -14.8000  -73.9167        51
# 53    new norfolk      AU -42.7826  147.0587        61
# 85    novyy urgal      RU  51.0736  132.5642        85
# 108      taskopru      TR  41.5098   34.2141        87
# 167      kangding      CN  30.0513  101.9603        87
# 183   kongsvinger      NO  60.1905   11.9977        77
# 251     tucumcari      US  35.1717 -103.7250        60
# 285     ilulissat      GL  69.2167  -51.1000        93
# 306      jincheng      CN  35.5022  112.8328        98
# 307         ancud      CL -41.8697  -73.8203        70
# 341          hovd      MN  48.0056   91.6419        39
# 351      smithers      CA  54.7804 -127.1743        93
# 357  puerto aysen      CL -45.4000  -72.7000        87
# 377      karliova      TR  39.2983   41.0142        83
# 387    mishelevka      RU  52.8575  103.1719        68
# 393       quellon      CL -43.1167  -73.6167       100
# 401      bereznik      RU  62.8551   42.7072        74
# 430       chonchi      CL -42.6128  -73.8092        73
# 434        hinton      CA  53.4001 -117.5857        83
# 451      akureyri      IS  65.6835  -18.0878        35
# 462     rio bueno      CL -40.3167  -72.9667        61
# 516   akdagmadeni      TR  39.6603   35.8836        76
#
#                             Hotel Name
# 28                      No hotel found
# 53           Woodbridge on the Derwent
# 85                      No hotel found
# 108                        Poyraz Otel
# 167                     Kalakaer hotel
# 183                      Vinger hotell
# 251                        Pow Wow Inn
# 285  Best Western Plus Hotel Ilulissat
# 306                               德豪宾馆
# 307                            Cabañas
# 341                        Khovd hotel
# 351                 Sunshine Inn Hotel
# 357                      Hostal Dendal
# 377                     No hotel found
# 387                     No hotel found
# 393                             Aliwen
# 401                   Отель Прибрежный
# 430                      Hotel Huildín
# 434                   Timberland Hotel
# 451                   Hótel Norðurland
# 462                     No hotel found
# 516                     No hotel found

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
#%%capture --no-display

# Configure the map plot
# YOUR CODE HERE
map_plot = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Humidity",
    scale = 0.5,
    color = "City",
    hover_cols = ["Hotel Name","Country"]
)

# Display the map
# YOUR CODE HERE
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
